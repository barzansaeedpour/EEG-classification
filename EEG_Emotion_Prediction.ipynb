# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# copying files from google drive to the colab workspace. you can just simply upload the dataset by yourself

# %%
# !cp -r "/content/drive/MyDrive/Colab/EEG-machine-learning/datasets" "/content/"

# %%
# This program aims to accurately predict the emotional states of a subject while watching various movie scenes given their EEG readings using a recurrent neural network
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('/content/datasets/emotions.csv')

# %%
data
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0          4.620      30.3    -356.0     15.60      26.3       1.070
# 1         28.800      33.1      32.0     25.80      22.8       6.550
# 2          8.900      29.4    -416.0     16.70      23.7      79.900
# 3         14.900      31.6    -143.0     19.80      24.3      -0.584
# 4         28.300      31.3      45.2     27.30      24.5      34.800
# ...          ...       ...       ...       ...       ...         ...
# 2127      32.400      32.2      32.2     30.80      23.4       1.640
# 2128      16.300      31.3    -284.0     14.30      23.9       4.200
# 2129      -0.547      28.3    -259.0     15.80      26.7       9.080
# 2130      16.800      19.9    -288.0      8.34      26.0       2.460
# 2131      27.000      32.0      31.8     25.00      28.9       4.990
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  \
# ...

# %%
sample = data.loc[0, 'fft_0_b':'fft_749_b']
plt.figure(figsize=(16, 10))
plt.plot(range(len(sample)), sample)
plt.title('Feautures fft_0_b through fft_749_b')
plt.show()

# %%
data['label'].value_counts()
# Out:
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: label, dtype: int64

# %%
label_mapping = {'NEGATIVE': 0, 'NEUTRAL': 1, 'POSITIVE': 2}

# %%
def preprocess_inputs(df):
  df = df.copy()

  df['label'] = df['label'].replace(label_mapping)

  y = df['label'].copy()
  X = df.drop('label', axis=1).copy()

  X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)

# %%
X_train
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 993       14.400      29.7    -112.0     18.50      22.9    -3.63000
# 1851      13.700      22.8      21.5      8.40      27.1     3.27000
# 1253      -0.765      24.7    -578.0     11.90      27.9    -1.44000
# 1228      28.200      32.6      32.1     30.30      24.6    -0.00524
# 1461      31.900      31.0      34.4     30.80      24.0    -4.74000
# ...          ...       ...       ...       ...       ...         ...
# 1593       6.820      32.9    -741.0     32.60      27.0    -0.41300
# 1147      31.500      32.1      31.3     28.80      25.0     5.32000
# 1766     -11.800      26.3    -828.0      7.68      23.3    13.10000
# 1122      27.600      32.2      28.8     25.60      24.1    -6.94000
# 1346      13.700      29.6    -204.0     11.40      29.9     4.50000
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_740_b  \
# ...

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))

expand_dims = tf.expand_dims(inputs, axis=2)
gru = tf.keras.layers.GRU(256, return_sequences=True)(expand_dims)
flatten = tf.keras.layers.Flatten()(gru)
outputs = tf.keras.layers.Dense(3, activation='softmax')(flatten)

model = tf.keras.Model(inputs=inputs, outputs=outputs)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 2548)]            0
#
#  tf.expand_dims (TFOpLambda  (None, 2548, 1)           0
#  )
#
#  gru (GRU)                   (None, 2548, 256)         198912
#
#  flatten (Flatten)           (None, 652288)            0
#
#  dense (Dense)               (None, 3)                 1956867
#
# ...
# Total params: 2155779 (8.22 MB)
# Trainable params: 2155779 (8.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# You can also use a more advanced RNN:

# %%
# import tensorflow as tf
# # Define input shape
# input_shape = X_train.shape[1]

# # Create input layer
# inputs = tf.keras.Input(shape=(input_shape,))

# # Embedding layer for input preprocessing
# embedding = tf.keras.layers.Embedding(input_dim=input_shape, output_dim=128)(inputs)

# # Bidirectional GRU layers with dropout
# gru1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True, dropout=0.2))(embedding)
# gru2 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True, dropout=0.2))(gru1)

# # Global max pooling layer
# global_max_pooling = tf.keras.layers.GlobalMaxPooling1D()(gru2)

# # Dense layer for classification
# dense = tf.keras.layers.Dense(64, activation='relu')(global_max_pooling)

# # Output layer
# outputs = tf.keras.layers.Dense(3, activation='softmax')(dense)

# # Define model
# model = tf.keras.Model(inputs=inputs, outputs=outputs)

# # Compile model
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# # Print model summary
# print(model.summary())

# %% [markdown]
# To chekck if GPU is available:

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print(gpu)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=50,
    # callbacks=[
    #     tf.keras.callbacks.EarlyStopping(
    #         monitor='val_loss',
    #         patience=5,
    #         restore_best_weights=True
    #     )
    # ]
)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 8s 134ms/step - loss: 12.9825 - accuracy: 0.8340 - val_loss: 15.2387 - val_accuracy: 0.8896
# Epoch 2/50
# 38/38 [==============================] - 4s 113ms/step - loss: 6.8572 - accuracy: 0.9061 - val_loss: 4.4995 - val_accuracy: 0.9164
# Epoch 3/50
# 38/38 [==============================] - 4s 117ms/step - loss: 2.3200 - accuracy: 0.9539 - val_loss: 2.1158 - val_accuracy: 0.9365
# Epoch 4/50
# 38/38 [==============================] - 4s 118ms/step - loss: 0.6697 - accuracy: 0.9824 - val_loss: 4.5702 - val_accuracy: 0.9498
# Epoch 5/50
# 38/38 [==============================] - 4s 108ms/step - loss: 0.5928 - accuracy: 0.9858 - val_loss: 2.8664 - val_accuracy: 0.9532
# Epoch 6/50
# 38/38 [==============================] - 8s 211ms/step - loss: 0.1403 - accuracy: 0.9958 - val_loss: 3.6007 - val_accuracy: 0.9465
# Epoch 7/50
# ...

# %%
model_acc = model.evaluate(X_test, y_test, verbose=0)[1]
print("Test Accuracy: {:.3f}%".format(model_acc * 100))
# Out:
# Test Accuracy: 96.250%

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), model.predict(X_test))))

cm = confusion_matrix(y_test, y_pred)
clr = classification_report(y_test, y_pred, target_names=label_mapping.keys())

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cbar=False, cmap='Blues')
plt.xticks(np.arange(3) + 0.5, label_mapping.keys())
plt.yticks(np.arange(3) + 0.5, label_mapping.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# 20/20 [==============================] - 1s 42ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#     NEGATIVE       0.91      1.00      0.95       201
#      NEUTRAL       1.00      0.99      0.99       231
#     POSITIVE       0.98      0.90      0.94       208
#
#     accuracy                           0.96       640
#    macro avg       0.96      0.96      0.96       640
# weighted avg       0.96      0.96      0.96       640
